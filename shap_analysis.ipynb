# %% [markdown]
# This is a temporary notebook for shap value analysis and plots.

# %%
import os
import sys

proj_dir = "/home/scai/PhenPred"
if not os.path.exists(proj_dir):
    proj_dir = "/Users/emanuel/Projects/PhenPred"
sys.path.extend([proj_dir])

import json
import PhenPred
import argparse
import pandas as pd
from PhenPred.vae import plot_folder
from PhenPred.vae.Hypers import Hypers
from PhenPred.vae.Train import CLinesTrain
from PhenPred.vae.DatasetDepMap23Q2 import CLinesDatasetDepMap23Q2
pd.set_option("display.max_rows", 100)
pd.set_option("display.max_columns", 100)

# %%
import shap
import pickle
from tqdm.notebook import tqdm

# %%
hyperparameters = Hypers.read_hyperparameters()
clines_db = CLinesDatasetDepMap23Q2(
        labels_names=hyperparameters["labels"],
        datasets=hyperparameters["datasets"],
        feature_miss_rate_thres=hyperparameters["feature_miss_rate_thres"],
        standardize=hyperparameters["standardize"],
        filter_features=hyperparameters["filter_features"],
        filtered_encoder_only=hyperparameters["filtered_encoder_only"],
    )
# Out:
# All-NaN slice encountered
# All-NaN slice encountered
# DepMap23Q2 | Samples = 1,523 | Proteomics = 4,922 (0 masked) | Metabolomics = 225 (0 masked) | Drug response = 810 (0 masked) | CRISPR-Cas9 = 17,931 (12,718 masked) | Methylation = 14,608 (7,018 masked) | Transcriptomics = 15,278 (7,200 masked) | Copy number = 777 (0 masked) | Labels = 237

# %%
clines_db.features_mask["crisprcas9"][
    clines_db.features_mask["crisprcas9"] == True
].index.values
# Out:
# array(['AAAS', 'AACS', 'AAMP', ..., 'ZWILCH', 'ZWINT', 'ZZZ3'],
#       dtype=object)

# %%
shap_values = pickle.load(open("./reports/vae/files/20230717_160108_shap_values.pkl", "rb"))

# %%
clines_db.view_names
# Out:
# ['proteomics',
#  'metabolomics',
#  'drugresponse',
#  'crisprcas9',
#  'methylation',
#  'transcriptomics',
#  'copynumber']

# %%
all_shap_df = []
for latent_dim in range(len(shap_values)):
    shap_latent = shap_values[latent_dim]
    latent_dfs = []
    for i in range(len(shap_latent)):
        view_name = clines_db.view_names[i]
        feature_names = clines_db.features_mask[view_name][clines_db.features_mask[view_name] == True].index.values
        tmp_df = pd.DataFrame(shap_latent[i], columns=feature_names, index=clines_db.samples)
        tmp_df.columns = [f"{clines_db.view_names[i]}_{c}" for c in tmp_df.columns]
        latent_dfs.append(tmp_df)
    latent_dfs = pd.concat(latent_dfs, axis=1)
    latent_dfs['latent_dim'] = f"latent_dim_{latent_dim}"
    
    all_shap_df.append(latent_dfs)
all_shap_df = pd.concat(all_shap_df, axis=0)
cols = all_shap_df.columns.tolist()
cols = [cols[-1]] + cols[:-1]
all_shap_df = all_shap_df[cols]
all_shap_df.index.name = 'model_id'

# %%
pickle.dump(all_shap_df, open("./reports/vae/files/20230717_160108_shap_values_df.pkl", "wb"))

# %%
all_shap_df = all_shap_df.reset_index()

# %%
all_shap_df.head()
# Out:
#     model_id    latent_dim  proteomics_AAAS  proteomics_AACS
# 0  SIDM00979  latent_dim_0         0.000114         0.000018  \
# 1  SIDM01548  latent_dim_0         0.000025         0.000006
# 2  SIDM01461  latent_dim_0         0.000024         0.000006
# 3  SIDM01762  latent_dim_0         0.000005         0.000170
# 4  SIDM01535  latent_dim_0         0.000004         0.000010
#
#    proteomics_AAGAB  proteomics_AAK1  proteomics_AAMDC  proteomics_AAMP
# 0          0.000035         0.000001          0.000007     5.732462e-07  \
# 1          0.000015         0.000004          0.000009     2.642014e-05
# 2          0.000046         0.000003          0.000006     2.589496e-05
# 3          0.000166         0.000051          0.000030     3.533704e-04
# 4          0.000156         0.000012          0.000053     2.288779e-05
#
#    proteomics_AARS1  proteomics_AARS2  ...  copynumber_ZNF521
# 0          0.000211          0.000310  ...           0.000089  \
# 1          0.000049          0.000024  ...           0.000044
# 2          0.000008          0.000076  ...           0.000013
# 3          0.000096          0.000040  ...           0.000009
# 4          0.000012          0.000079  ...           0.000016
#
#    copynumber_ZNF626  copynumber_ZNF680  copynumber_ZNF721
# 0           0.000054           0.000174                0.0  \
# 1           0.000133           0.000075                0.0
# 2           0.000057           0.000034                0.0
# 3           0.000002           0.000387                0.0
# 4           0.000332           0.000103                0.0
#
#    copynumber_ZNF780A  copynumber_ZNF814  copynumber_ZNF93  copynumber_ZNRF3
# 0            0.000009                0.0          0.000068          0.000335  \
# 1            0.000573                0.0          0.000198          0.000005
# 2            0.000020                0.0          0.000044          0.000077
# 3            0.000052                0.0          0.000002          0.000293
# 4            0.000087                0.0          0.000419          0.000215
#
#    copynumber_ZRSR2  copynumber_ZXDB
# 0          0.000007     1.205870e-06
# 1          0.000075     1.763348e-06
# 2          0.000039     4.379459e-06
# 3          0.000065     1.414212e-06
# 4          0.000038     4.189702e-07
#
# [5 rows x 27617 columns]

# %%
all_shap_df.iloc[:, 2:] = all_shap_df.iloc[:, 2:].abs()

# %%
shap_latent_sum_df = all_shap_df.drop(columns=['latent_dim']).groupby('model_id').sum()

# %%
shap_latent_sum_df.to_csv("./reports/vae/files/20230717_160108_shap_values_df_sum.csv.gz", compression="gzip")

# %%
shap_latent_sum_df
# Out:
#            proteomics_AAAS  proteomics_AACS  proteomics_AAGAB
# model_id
# SIDM00001         0.003697         0.001406          0.003262  \
# SIDM00003         0.034662         0.022374          0.002186
# SIDM00005         0.001372         0.001750          0.002804
# SIDM00006         0.020894         0.000914          0.002157
# SIDM00007         0.023611         0.000401          0.000548
# ...                    ...              ...               ...
# SIDM01979         0.039984         0.002751          0.003316
# SIDM01980         0.001849         0.001368          0.001304
# SIDM01981         0.044551         0.001731          0.000440
# SIDM01983         0.004391         0.004902          0.000934
# SIDM01985         0.034591         0.009657          0.034907
#
#            proteomics_AAK1  proteomics_AAMDC  proteomics_AAMP
# model_id
# SIDM00001         0.005072          0.000789         0.002053  \
# SIDM00003         0.042153          0.000288         0.003861
# SIDM00005         0.002103          0.002325         0.001615
# SIDM00006         0.003778          0.004461         0.048202
# SIDM00007         0.001215          0.002196         0.102766
# ...                    ...               ...              ...
# SIDM01979         0.001383          0.000562         0.001402
# SIDM01980         0.002682          0.001356         0.002207
# SIDM01981         0.022347          0.001248         0.032245
# SIDM01983         0.002534          0.003574         0.001807
# SIDM01985         0.031237          0.016336         0.031356
#
#            proteomics_AARS1  proteomics_AARS2  proteomics_AARSD1
# model_id
# SIDM00001          0.043771          0.032513           0.002895  \
# SIDM00003          0.025875          0.014182           0.035586
# SIDM00005          0.002041          0.006507           0.004368
# SIDM00006          0.018414          0.006017           0.007669
# SIDM00007          0.036635          0.002449           0.002661
# ...                     ...               ...                ...
# SIDM01979          0.037768          0.030038           0.001018
# SIDM01980          0.003816          0.001792           0.002646
# SIDM01981          0.014040          0.031690           0.008052
# SIDM01983          0.003184          0.008151           0.001771
# SIDM01985          0.010336          0.018017           0.020636
#
#            proteomics_AASDHPPT  ...  copynumber_ZNF521  copynumber_ZNF626
# model_id                        ...
# SIDM00001             0.004275  ...           0.010261           0.001493  \
# SIDM00003             0.013104  ...           0.015710           0.006088
# SIDM00005             0.002777  ...           0.000424           0.002268
# SIDM00006             0.033665  ...           0.001491           0.003719
# SIDM00007             0.024112  ...           0.009166           0.009298
# ...                        ...  ...                ...                ...
# SIDM01979             0.022441  ...           0.000434           0.037422
# SIDM01980             0.003522  ...           0.016046           0.006251
# SIDM01981             0.023979  ...           0.001110           0.008014
# SIDM01983             0.001353  ...           0.001824           0.004750
# SIDM01985             0.021308  ...           0.000772           0.005190
#
#            copynumber_ZNF680  copynumber_ZNF721  copynumber_ZNF780A
# model_id
# SIDM00001           0.052997                0.0            0.007929  \
# SIDM00003           0.009296                0.0            0.001322
# SIDM00005           0.021009                0.0            0.002722
# SIDM00006           0.048061                0.0            0.003779
# SIDM00007           0.013176                0.0            0.004039
# ...                      ...                ...                 ...
# SIDM01979           0.021612                0.0            0.069393
# SIDM01980           0.019593                0.0            0.009018
# SIDM01981           0.004350                0.0            0.007467
# SIDM01983           0.011958                0.0            0.006984
# SIDM01985           0.023590                0.0            0.001924
#
#            copynumber_ZNF814  copynumber_ZNF93  copynumber_ZNRF3
# model_id
# SIDM00001                0.0          0.001717          0.025623  \
# SIDM00003                0.0          0.006920          0.034975
# SIDM00005                0.0          0.002500          0.002279
# SIDM00006                0.0          0.004092          0.004947
# SIDM00007                0.0          0.010539          0.025728
# ...                      ...               ...               ...
# SIDM01979                0.0          0.042246          0.002689
# SIDM01980                0.0          0.008165          0.042779
# SIDM01981                0.0          0.007093          0.004312
# SIDM01983                0.0          0.005253          0.004120
# SIDM01985                0.0          0.005763          0.000632
#
#            copynumber_ZRSR2  copynumber_ZXDB
# model_id
# SIDM00001          0.006783         0.000238
# SIDM00003          0.058536         0.003467
# SIDM00005          0.004432         0.000075
# SIDM00006          0.008841         0.000225
# SIDM00007          0.052882         0.000036
# ...                     ...              ...
# SIDM01979          0.006359         0.003348
# SIDM01980          0.006722         0.000124
# SIDM01981          0.003191         0.000160
# SIDM01983          0.007217         0.000422
# SIDM01985          0.004461         0.000080
#
# [1523 rows x 27615 columns]

# %%
global_feature_importance_df = (
    shap_latent_sum_df.mean()
    .sort_values(ascending=False)
    .reset_index(name="importance")
)
global_feature_importance_df.rename(columns={"index": "feature"}, inplace=True)

# %%
global_feature_importance_df.to_csv("./reports/vae/files/20230717_160108_shap_values_df_sum_global.csv", index=False)

# %%
global_feature_importance_df[global_feature_importance_df['feature'].str.contains('drugresponse')].head(100)
# Out:
#                                                feature  importance
# 95                  drugresponse_1372;Trametinib;GDSC2    0.136074
# 99                     drugresponse_1015;CI-1040;GDSC1    0.132009
# 105                  drugresponse_1564;SCH772984;GDSC2    0.129097
# 106                  drugresponse_283;Omipalisib;GDSC1    0.128630
# 107                  drugresponse_1060;PD0325901;GDSC2    0.126859
# 109                   drugresponse_235;QL-XII-47;GDSC1    0.126645
# 123                 drugresponse_1372;Trametinib;GDSC1    0.120806
# 133                      drugresponse_1494;SN-38;GDSC1    0.116741
# 135                  drugresponse_1558;Lapatinib;GDSC2    0.115164
# 144                   drugresponse_282;Pelitinib;GDSC1    0.111958
# 145                      drugresponse_262;VX-11e;GDSC1    0.111554
# 149                  drugresponse_291;KIN001-266;GDSC1    0.110339
# 153                drugresponse_1908;Ulixertinib;GDSC2    0.109280
# 158                    drugresponse_344;THZ-2-49;GDSC1    0.107278
# 162  drugresponse_1374;Dabrafenib (1373) + Trametin...    0.105335
# 163                drugresponse_1014;Refametinib;GDSC1    0.105179
# 165                   drugresponse_256;JW-7-24-1;GDSC1    0.104044
# 166                     drugresponse_299;OSI-027;GDSC1    0.103476
# 167  drugresponse_1376;Olaparib(1495) + Temozolomid...    0.103366
# 168                  drugresponse_1561;Taselisib;GDSC2    0.102707
# 169                     drugresponse_304;SB52334;GDSC1    0.102566
# 172                   drugresponse_263;FR-180204;GDSC1    0.101774
# 174                     drugresponse_223;ZSTK474;GDSC1    0.101550
# 175                    drugresponse_331;QL-X-138;GDSC1    0.101243
# 177                     drugresponse_156;AZD6482;GDSC1    0.100808
# 181                 drugresponse_1058;Pictilisib;GDSC2    0.100583
# 182                  drugresponse_1060;PD0325901;GDSC1    0.100563
# 184                     drugresponse_2096;VX-11e;GDSC2    0.100188
# 187                      drugresponse_302;PI-103;GDSC1    0.099227
# 188                drugresponse_1526;Refametinib;GDSC1    0.099050
# 189                    drugresponse_310;YM201636;GDSC1    0.098965
# 191                    drugresponse_1053;MK-2206;GDSC2    0.098766
# 192                      drugresponse_1425;BPTES;GDSC1    0.097894
# 193                 drugresponse_229;Enzastaurin;GDSC1    0.097847
# 194          drugresponse_228;AKT inhibitor VIII;GDSC1    0.097291
# 196                   drugresponse_1050;ZM447439;GDSC1    0.096769
# 197                     drugresponse_245;UNC0638;GDSC1    0.096482
# 198                     drugresponse_288;WHI-P97;GDSC1    0.096349
# 199                drugresponse_1498;Selumetinib;GDSC1    0.096320
# 200                  drugresponse_1560;Alpelisib;GDSC2    0.094977
# 202                  drugresponse_287;KIN001-244;GDSC1    0.094417
# 203                drugresponse_1393;Gemcitabine;GDSC1    0.094143
# 205                    drugresponse_381;AST-1306;GDSC1    0.093925
# 206                   drugresponse_326;GSK690693;GDSC1    0.093767
# 207          drugresponse_1378;Bleomycin (50 uM);GDSC1    0.093177
# 209                  drugresponse_1007;Docetaxel;GDSC1    0.092970
# 212                   drugresponse_1032;Afatinib;GDSC2    0.092418
# 213                      drugresponse_303;PIK-93;GDSC1    0.092292
# 214                    drugresponse_1918;AZD8186;GDSC2    0.091220
# 216                  drugresponse_294;MPS-1-IN-1;GDSC1    0.090588
# 217                  drugresponse_1496;Cisplatin;GDSC1    0.090326
# 220                     drugresponse_362;CI-1033;GDSC1    0.089403
# 221                    drugresponse_224;AS605240;GDSC1    0.089016
# 222                  drugresponse_1460;PARP_9482;GDSC1    0.088678
# 223                drugresponse_1386;Doxorubicin;GDSC1    0.088568
# 224                drugresponse_1054;Palbociclib;GDSC2    0.088466
# 225                drugresponse_1259;Talazoparib;GDSC1    0.088054
# 226                  drugresponse_1459;PARP_0108;GDSC1    0.087769
# 228                     drugresponse_172;Embelin;GDSC1    0.087079
# 229                  drugresponse_1549;Sapatinib;GDSC2    0.086747
# 230                    drugresponse_1394;AZD6738;GDSC1    0.086734
# 231                  drugresponse_1005;Cisplatin;GDSC1    0.086695
# 234          drugresponse_1392;Bleomycin (10 uM);GDSC1    0.086200
# 235                   drugresponse_1453;RAF_9304;GDSC1    0.086008
# 236                  drugresponse_1430;IGFR_3801;GDSC1    0.085873
# 237                 drugresponse_363;PF-00299804;GDSC1    0.085706
# 238                 drugresponse_1006;Cytarabine;GDSC1    0.085436
# 240                   drugresponse_1495;Olaparib;GDSC1    0.085350
# 243                    drugresponse_1441;AZD2014;GDSC1    0.084921
# 244                       drugresponse_1864;R428;GDSC2    0.084863
# 245                drugresponse_1062;Selumetinib;GDSC1    0.084633
# 246                    drugresponse_1926;GNE-317;GDSC2    0.084075
# 247               drugresponse_1026;Tanespimycin;GDSC1    0.083901
# 248                drugresponse_1924;Ipatasertib;GDSC2    0.083672
# 249                 drugresponse_1413;EphB4_9721;GDSC1    0.083360
# 250              drugresponse_437;Trichostatin A;GDSC1    0.083332
# 251                  drugresponse_382;Apitolisib;GDSC1    0.083256
# 254          drugresponse_171;AKT inhibitor VIII;GDSC1    0.083088
# 256                drugresponse_201;Epothilone B;GDSC1    0.083028
# 257                  drugresponse_1084;Rapamycin;GDSC2    0.082785
# 258                    drugresponse_279;BIX02189;GDSC1    0.082703
# 259                   drugresponse_342;Tenovin-6;GDSC1    0.082692
# 261                   drugresponse_308;Foretinib;GDSC1    0.081506
# 263              drugresponse_1034;Staurosporine;GDSC2    0.081073
# 264                      drugresponse_252;WZ3105;GDSC1    0.081046
# 265                 drugresponse_1091;BMS-536924;GDSC1    0.080943
# 267                 drugresponse_140;Vinorelbine;GDSC1    0.080722
# 268                  drugresponse_203;BMS-345541;GDSC1    0.080427
# 269                 drugresponse_1192;GSK269962A;GDSC1    0.080367
# 270                  drugresponse_306;Fedratinib;GDSC1    0.080312
# 271                    drugresponse_329;QL-XI-92;GDSC1    0.080296
# 272                  drugresponse_1419;FEN1_3940;GDSC1    0.080044
# 275                   drugresponse_1032;Afatinib;GDSC1    0.079619
# 276                  drugresponse_1019;Bosutinib;GDSC1    0.079553
# 277                  drugresponse_295;NVP-BHG712;GDSC1    0.079000
# 278                drugresponse_1919;Osimertinib;GDSC2    0.078999
# 279                  drugresponse_204;Tipifarnib;GDSC1    0.078969
# 280                   drugresponse_1464;TTK_3146;GDSC1    0.078952
# 281                      drugresponse_356;AT7867;GDSC1    0.078944
# 283                  drugresponse_1422;FGFR_3831;GDSC1    0.078709

# %%
global_feature_importance_df[global_feature_importance_df['feature'].str.contains('mutations')].head(100)
# Out:
# Empty DataFrame
# Columns: [feature, importance]
# Index: []
